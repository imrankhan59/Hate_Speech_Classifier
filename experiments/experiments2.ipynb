# %%
import os
import pandas as pd
import numpy as np

# %%
  data_ingestion:
    cmd: python src/components/data_ingestion.py
    deps:
      - src/components/data_ingestion.py
    outs:
      - artifacts/DataIngestionArtifacts/raw_data.csv
      - artifacts/DataIngestionArtifacts/imb_data.csv

# %%
raw_data = pd.read_csv(r"C:\Users\HP\Desktop\raw_data.csv")

# %%
imb_data = pd.read_csv(r"C:\Users\HP\Desktop\imbalanced_data.csv")

# %%
raw_data.head()
# Out:
#    count  hate_speech  offensive_language  neither  class  \
# 0      3            0                   0        3      2
# 1      3            0                   3        0      1
# 2      3            0                   3        0      1
# 3      3            0                   2        1      1
# 4      6            0                   6        0      1
#
#                                                tweet
# 0  !!! RT @mayasolovely: As a woman you shouldn't...
# 1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...

# %%
"""mongodb+srv://imrankhan:ik565375#@cluster0.7whv9os.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"""
# Out:
# 'mongodb+srv://imrankhan:ik565375#@cluster0.7whv9os.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
raw_data_c = raw_data.to_dict(orient="records")
imb_data_c = imb_data.to_dict(orient="records")

# %%
DB_NAME = "NLP"
COLLECTION_NAME = "NLP_DATA"
CONNECTION_URL = "mongodb+srv://imrankhan:ik565375#@cluster0.7whv9os.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
db = client[DB_NAME]
collection = db[COLLECTION_NAME]

# %%
collection.insert_one({
    "dataset": "raw_data",
    "data": raw_data_c  # raw_data_c is a list of dicts
})
# Out:
# InsertOneResult(ObjectId('68c003a27652f58bdec58df8'), acknowledged=True)

# %%
collection.insert_one({
    "dataset": "imb_data",
    "data": imb_data_c
})
# Out:
# InsertOneResult(ObjectId('68c003d57652f58bdec58df9'), acknowledged=True)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
collection.insert_many(raw_data_c)
# Out:
# InsertManyResult([ObjectId('68beba037652f58bdec4b051'), ObjectId('68beba037652f58bdec4b052'), ObjectId('68beba037652f58bdec4b053'), ObjectId('68beba037652f58bdec4b054'), ObjectId('68beba037652f58bdec4b055'), ObjectId('68beba037652f58bdec4b056'), ObjectId('68beba037652f58bdec4b057'), ObjectId('68beba037652f58bdec4b058'), ObjectId('68beba037652f58bdec4b059'), ObjectId('68beba037652f58bdec4b05a'), ObjectId('68beba037652f58bdec4b05b'), ObjectId('68beba037652f58bdec4b05c'), ObjectId('68beba037652f58bdec4b05d'), ObjectId('68beba037652f58bdec4b05e'), ObjectId('68beba037652f58bdec4b05f'), ObjectId('68beba037652f58bdec4b060'), ObjectId('68beba037652f58bdec4b061'), ObjectId('68beba037652f58bdec4b062'), ObjectId('68beba037652f58bdec4b063'), ObjectId('68beba037652f58bdec4b064'), ObjectId('68beba037652f58bdec4b065'), ObjectId('68beba037652f58bdec4b066'), ObjectId('68beba037652f58bdec4b067'), ObjectId('68beba037652f58bdec4b068'), ObjectId('68beba037652f58bdec4b069'), ObjectId('68beba037652f58bdec4
# ...

# %%
collection.insert_many(imb_data_c)
# Out:
# InsertManyResult([ObjectId('68beba227652f58bdec5111e'), ObjectId('68beba227652f58bdec5111f'), ObjectId('68beba227652f58bdec51120'), ObjectId('68beba227652f58bdec51121'), ObjectId('68beba227652f58bdec51122'), ObjectId('68beba227652f58bdec51123'), ObjectId('68beba227652f58bdec51124'), ObjectId('68beba227652f58bdec51125'), ObjectId('68beba227652f58bdec51126'), ObjectId('68beba227652f58bdec51127'), ObjectId('68beba227652f58bdec51128'), ObjectId('68beba227652f58bdec51129'), ObjectId('68beba227652f58bdec5112a'), ObjectId('68beba227652f58bdec5112b'), ObjectId('68beba227652f58bdec5112c'), ObjectId('68beba227652f58bdec5112d'), ObjectId('68beba227652f58bdec5112e'), ObjectId('68beba227652f58bdec5112f'), ObjectId('68beba227652f58bdec51130'), ObjectId('68beba227652f58bdec51131'), ObjectId('68beba227652f58bdec51132'), ObjectId('68beba227652f58bdec51133'), ObjectId('68beba227652f58bdec51134'), ObjectId('68beba227652f58bdec51135'), ObjectId('68beba227652f58bdec51136'), ObjectId('68beba227652f58bdec5
# ...

# %%
records = collection.find()
